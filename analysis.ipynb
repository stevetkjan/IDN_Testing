# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import imagehash
import subprocess
import tempfile,shutil
path1 = './'

vidcap = cv2.VideoCapture('./Chrome_81_MacOS Catalina.mov')
success, prev = vidcap.read()
success, image = vidcap.read()


count = counter = 0



def run_tesseract(image_file_name):
    filename = 'temp'
    temp_dir = tempfile.mkdtemp()
    temp_file = os.path.join(temp_dir, filename)
    subprocess.run(['tesseract', image_file_name, temp_file],
                       stdout=subprocess.PIPE,
                       stderr=subprocess.PIPE)
    with open('{}.txt'.format(temp_file), 'r', encoding="utf8") as f:
        text = f.read()
    shutil.rmtree(temp_dir)

    return text


threshold = 100
while success:
    hash1 = imagehash.phash( Image.fromarray(np.uint8(prev)).convert('L')  )
    hash2 = imagehash.phash( Image.fromarray(np.uint8(image)).convert('L')  )
    if counter == 300:
        break
    
    if hash1 - hash2 < 10:
        success,image = vidcap.read()
        continue
    else:
        
        plt.imshow(image)
        plt.show()
        
        img = cv2.resize(image, None, fx=10, fy=10, interpolation=cv2.INTER_CUBIC)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        (thresh, img) = cv2.threshold(img, threshold, 255, cv2.THRESH_BINARY) 
        
        img = cv2.bitwise_not(img)
        cv2.imwrite(path1+"frame%d.jpg" % int(counter), img) 
        
        text1 = run_tesseract(path1+"frame%d.jpg" % int(counter)).strip()
        print(text1)
        counter += 1
    prev = image
    success,image = vidcap.read()

    count += 1
# Out:
# ORLOD » PYLUTUOT
#
# --fPEOulls 7 -Lofll
# ~~ Eg
# Not | data:,
# Not Se: | data:,
# Not Secu | data:,
# Not Secur | data:,
# aaaaaa---al.com
# xn--a-8sb.com
# bbbbbb---a2.com
# xn--a-jOm.com
# aaaaaa---a3.com
# xnN--a-cib.com
# bbbbbb---a4.com
# xn--a-4/sS.com
# aaaaaa---ab.com
# xn--a-5j3e.com
# bbbbbb---a6.com
# xn--a-f5b.com
# aaaaaa---a/.com
# xn--80a448k.com
# bbbbbb---a8.com
# xn--sva59a.com
# aaaaaa---a9.com
# xn--engx89c.com
# bbbbbb---a10.com
# xn--sva148s.com
# aaaaaa---al11.com
# xn--eng0934c.com
# bbbbbb---a12.com
# xn--sva//44f.com
# aaaaaa---a13.com
# xn--c/a814k.com
# bbbbbb---a14.com
# xn--sval2f.com
# aaaaaa---al15.com
# xn--Oda04n.com
# bDbbbbb---a16.com
# xn--Oda074m.com
# aaaaaa---al/.com
# xn--Oda85j.com
# bbbbbb---a18.com
# xn--Oda680u.com
# aaaaaa---a19.com
# xn--Oda2275f.com
# bbbbbb---a20.com
# xn--Oda66r.com
# aaaaaa---a21.com
# xn--lhaQ9k.com
# bbbbbb---a22.com
# xn--Iha0Q22m.com
# aaaaaa---a23.com
# xn--lha80h.com
# bbbbbb---a24.com
# xn--lha638t.com
# ...
